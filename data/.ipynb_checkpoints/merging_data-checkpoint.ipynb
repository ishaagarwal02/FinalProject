# %%
import pandas as pd

# %%
college_1257 = pd.read_csv('college.csv')

# %%
to_merge_6440 = pd.read_excel('nicole-klassen-level-1-university-admissions-data/University Directory Information with lables_2020.xlsx')
to_merge_6440.shape
# Out:
# (6440, 50)

# %%
to_merge_1989 = pd.read_excel('nicole-klassen-level-1-university-admissions-data/University Admissions with lables_2020.xlsx')
to_merge_1989.shape
# Out:
# (1989, 39)

# %%
college_1557 = pd.read_csv('Data-Table 1.csv')

# %%
merged = to_merge_6440.merge(to_merge_1989, on ='Unique identification number of the institution')

# %%
merged = merged.merge(college_1557, right_on='Name', left_on='Institution (entity) name')

# %%
merged = merged.merge(college_1257, right_on='Name', left_on='Institution (entity) name')

# %%
merged
# Out:
#       Unique identification number of the institution  \
# 0                                              100654
# 1                                              100663
# 2                                              100706
# 3                                              100724
# 4                                              100751
# ...                                               ...
# 1128                                           409698
# 1129                                           433660
# 1130                                           441937
# 1131                                           486840
# 1132                                           487524
#
#                         Institution (entity) name  \
# 0                        Alabama A & M University
# 1             University of Alabama at Birmingham
# 2             University of Alabama in Huntsville
# 3                        Alabama State University
# 4                       The University of Alabama
# ...
